# %%
import matplotlib.pyplot as plt

# Accuracies for Dataset 1
decisionTreeAcc = 0
KNNAcc = 93.6
LRAcc = 90.3
SVMAcc = 98.2
RFAcc = 96.5
BoostAcc = 0



# Assuming model names and their corresponding accuracies are provided in these lists
model_names = ["Decision Tree", "KNN", "Logistic Regression", "SVM", "Random Forest", "Boosting"]  # Fill in the model names
accuracies = [decisionTreeAcc, KNNAcc, LRAcc, SVMAcc, RFAcc, BoostAcc]  # Fill in the accuracies for each model

plt.figure(figsize=(10, 6))
plt.bar(model_names, accuracies, color='skyblue')
plt.xlabel('Model Names')
plt.ylabel('Accuracies')
plt.title('Comparison of Model Accuracies for Dataset 1')
plt.xticks(rotation=45)  # Rotate the model names for better readability
plt.show()


# Accuracies for Dataset 2
decisionTreeAcc = 0
KNNAcc = 66.1
LRAcc = 72.4
SVMAcc = 76.3
RFAcc = 66.7
BoostAcc = 0



# Assuming model names and their corresponding accuracies are provided in these lists
model_names = ["Decision Tree", "KNN", "Logistic Regression", "SVM", "Random Forest", "Boosting"]  # Fill in the model names
accuracies = [decisionTreeAcc, KNNAcc, LRAcc, SVMAcc, RFAcc, BoostAcc]  # Fill in the accuracies for each model

plt.figure(figsize=(10, 6))
plt.bar(model_names, accuracies, color='skyblue')
plt.xlabel('Model Names')
plt.ylabel('Accuracies')
plt.title('Comparison of Model Accuracies for Dataset 2')
plt.xticks(rotation=45)  # Rotate the model names for better readability
plt.show()
